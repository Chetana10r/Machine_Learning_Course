# %%
sentence="The Eiffel Tower was built from 1887 to 1889 by French engineer Gustave Eiffel, whose company specialized in building metal frameworks and structures"

# %%
import nltk
import sys
import os

# Define a directory to store the NLTK data within your Anaconda environment
# This path is based on your previous traceback, assuming you are in a base environment.
download_dir = os.path.join(sys.prefix, 'nltk_data')

# Create the directory if it doesn't exist
os.makedirs(download_dir, exist_ok=True)

# Download all necessary packages to the specified directory
nltk.download('maxent_ne_chunker', download_dir=download_dir)
nltk.download('punkt', download_dir=download_dir)
nltk.download('averaged_perceptron_tagger', download_dir=download_dir)
nltk.download('words', download_dir=download_dir)
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     c:\Users\cheta\anaconda3\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     c:\Users\cheta\anaconda3\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     c:\Users\cheta\anaconda3\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package words to
# [nltk_data]     c:\Users\cheta\anaconda3\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from nltk.chunk import ne_chunk

# %%
import nltk
nltk.download('maxent_ne_chunker')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     c:\Users\cheta\anaconda3\share\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# True

# %%
nltk.download('punkt') # for word_tokenize
nltk.download('averaged_perceptron_tagger') # for pos_tag
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     c:\Users\cheta\anaconda3\share\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     c:\Users\cheta\anaconda3\share\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
import nltk
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     c:\Users\cheta\anaconda3\share\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
import nltk
words=nltk.word_tokenize(sentence)

# %%
tag_elements=nltk.pos_tag(words)
