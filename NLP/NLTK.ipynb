# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\cheta\anaconda3\lib\site-packages (3.9.1)
# Requirement already satisfied: click in c:\users\cheta\anaconda3\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\cheta\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\cheta\anaconda3\lib\site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\cheta\anaconda3\lib\site-packages (from nltk) (4.66.5)
# Requirement already satisfied: colorama in c:\users\cheta\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
corpus=''' Hello Welcome, to chetana rane NLP learning sessions.
please do watch the entire course! to become expert in NLP.
'''

# %%
print(corpus)
# Out:
#  Hello Welcome, to chetana rane NLP learning sessions.
# please do watch the entire course! to become expert in NLP.

# %% [markdown]
# Tokenisation

# %% [markdown]
# Sentence--->Paragraphs

# %%
from nltk.tokenize import sent_tokenize

# %%
documents=sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
#  Hello Welcome, to chetana rane NLP learning sessions.
# please do watch the entire course!
# to become expert in NLP.

# %% [markdown]
# paragraph--->words

# %% [markdown]
# sentence--->words

# %%
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'chetana',
#  'rane',
#  'NLP',
#  'learning',
#  'sessions',
#  '.',
#  'please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'Welcome', ',', 'to', 'chetana', 'rane', 'NLP', 'learning', 'sessions', '.']
# ['please', 'do', 'watch', 'the', 'entire', 'course', '!']
# ['to', 'become', 'expert', 'in', 'NLP', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'chetana',
#  'rane',
#  'NLP',
#  'learning',
#  'sessions',
#  '.',
#  'please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer = TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'chetana',
#  'rane',
#  'NLP',
#  'learning',
#  'sessions.',
#  'please',
#  'do',
#  'watch',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']
